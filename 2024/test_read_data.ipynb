# %%
import pandas as pd
import numpy as np

# %%
DATA_PATH = 'drive/MyDrive/march_madness/2024/'

# %%
df_Mteams = pd.read_csv(DATA_PATH + 'march-machine-learning-mania-2024/MTeams.csv').drop(columns=['FirstD1Season', 'LastD1Season'])
df_Wteams = pd.read_csv(DATA_PATH + 'march-machine-learning-mania-2024/WTeams.csv')
df_Wteams
# Out:
#      TeamID          TeamName
# 0      3101       Abilene Chr
# 1      3102         Air Force
# 2      3103             Akron
# 3      3104           Alabama
# 4      3105       Alabama A&M
# ..      ...               ...
# 371    3474         Queens NC
# 372    3475  Southern Indiana
# 373    3476         Stonehill
# 374    3477   TX A&M Commerce
# 375    3478          Le Moyne
#
# [376 rows x 2 columns]

# %%
df_SOS = pd.DataFrame()

for yr in range(2003, 2024):
  df = pd.read_html(f'https://www.sports-reference.com/cbb/seasons/women/{yr}-ratings.html#ratings')[0]
  df = df.droplevel(0, axis=1)[['School', 'SOS']].dropna()
  df = df[df['School'] != 'School'].reset_index(drop=True)
  df['Season'] = np.ones(df.shape[0], dtype=int)*yr
  df_SOS = pd.concat([df_SOS,df])

df_SOS = df_SOS.reset_index(drop=True)
print(df_SOS.shape)
df_SOS

# %%
df_SOS = pd.read_csv(DATA_PATH + 'sports_ref_W2003.csv')[['School', 'SOS']]
df_SOS = df_SOS[df_SOS['School'] != 'School'].reset_index(drop=True)
df_SOS['Season'] = np.ones(df_SOS.shape[0], dtype=int)*2003
df_SOS
# Out:
#                        School    SOS  Season
# 0              South Carolina  15.70    2003
# 1             Louisiana State  10.78    2003
# 2                 Connecticut  16.96    2003
# 3                    Stanford  15.99    2003
# 4                     Indiana  14.66    2003
# ..                        ...    ...     ...
# 356       Charleston Southern  -9.79    2003
# 357  Mississippi Valley State  -8.37    2003
# 358      South Carolina State  -9.03    2003
# 359             Chicago State  -7.92    2003
# 360                  Hartford -13.87    2003
#
# [361 rows x 3 columns]

# %%
df_WSOS = df_Wteams.merge(df_SOS, right_on='School', left_on='TeamName', how='outer')
df_WSOS[df_WSOS.SOS.isna()]
# Out:
#      TeamID         TeamName School  SOS  Season
# 0    3101.0      Abilene Chr    NaN  NaN     NaN
# 5    3106.0       Alabama St    NaN  NaN     NaN
# 6    3107.0      SUNY Albany    NaN  NaN     NaN
# 7    3108.0        Alcorn St    NaN  NaN     NaN
# 8    3109.0     Alliant Intl    NaN  NaN     NaN
# ..      ...              ...    ...  ...     ...
# 367  3470.0      Tarleton St    NaN  NaN     NaN
# 369  3472.0     St Thomas MN    NaN  NaN     NaN
# 371  3474.0        Queens NC    NaN  NaN     NaN
# 374  3477.0  TX A&M Commerce    NaN  NaN     NaN
# 375  3478.0         Le Moyne    NaN  NaN     NaN
#
# [164 rows x 5 columns]

# %%
df_SOS[df_SOS.School == 'Abilene Christian'].School = 'Abilene Chr'
# Out:
# <ipython-input-26-41a615024ed1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_SOS[df_SOS.School == 'Abilene Christian'].School = 'Abilene Chr'

# %%
df_SOS.to_csv(DATA_PATH + 'WStrengthOfSchedule.csv')

# %%
df_SOS = pd.DataFrame()

for yr in range(2003, 2024):
  df = pd.read_html(f'https://www.sports-reference.com/cbb/seasons/men/{yr}-ratings.html#ratings')[0]
  df = df.droplevel(0, axis=1)[['School', 'SOS']].dropna()
  df = df[df['School'] != 'School'].reset_index(drop=True)
  df['Season'] = np.ones(df.shape[0], dtype=int)*yr
  df_SOS = pd.concat([df_SOS,df])

df_SOS = df_SOS.reset_index(drop=True)
print(df_SOS.shape)
df_SOS

# %%
df_SOS.to_csv(DATA_PATH + 'MStrengthOfSchedule.csv')
